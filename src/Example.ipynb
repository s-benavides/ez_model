# %%
import model as model
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import time
import tqdm

# %%
# Nx,Ny,q_in,x_avg,c_0,skipmax
test= model.model(30,20,5,10,0.5,3)

# %%
q_ts = []
for i in tqdm.tqdm(range(10000)):
    test.step()
    q_ts.append(test.q_out)
#     if (i % 100) == 0:
#         time.sleep(1.00)
#         display.clear_output()#wait=True)
#         test.plot_all()
#         display.display(plt.gcf())
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [00:51<00:00, 194.75it/s]

# %%
test.plot_all()

# %%
test.plot_min()
